# %%
#替换为你的toke账号
token = "#copy your token provided by https://quantum.ibm.com/#"


from qiskit_ibm_runtime import QiskitRuntimeService
 
QiskitRuntimeService.save_account(
  token=token,
  channel="ibm_quantum",
    overwrite=True# `channel` distinguishes between different account types
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 5
#       1 #替换为你的toke账号
#       2 token = "#copy your token provided by https://quantum.ibm.com/#"
# ----> 5 from qiskit_ibm_runtime import QiskitRuntimeService
#       7 QiskitRuntimeService.save_account(
#       8   token=token,
#       9   channel="ibm_quantum",
#      10     overwrite=True# `channel` distinguishes between different account types
#      11 )
#
# File ~/miniforge3/envs/Tencent/lib/python3.11/site-packages/qiskit_ibm_runtime/__init__.py:204
#     201 import logging
#     202 import warnings
# --> 204 from .qiskit_runtime_service import QiskitRuntimeService
#     205 from .ibm_backend import IBMBackend
#     206 from .runtime_job import RuntimeJob
#
# File ~/miniforge3/envs/Tencent/lib/python3.11/site-packages/qiskit_ibm_runtime/qiskit_runtime_service.py:22
#      19 from collections import OrderedDict
#      20 from typing import Dict, Callable, Optional, Union, List, Any, Type, Sequence, Tuple
# ---> 22 from qiskit.providers.backend import BackendV2 as Backend
#      23 from qiskit.providers.exceptions import QiskitBackendNotFoundError
#      24 from qiskit.providers.providerutils import filter_backends
#
# File ~/miniforge3/envs/Tencent/lib/python3.11/site-packages/qiskit/providers/backend.py:23
#      20 import datetime
#      21 from typing import List, Union, Tuple
# ---> 23 from qiskit.circuit.gate import Instruction
#      26 class Backend:
#      27     """Base common type for all versioned Backend abstract classes.
#      28
#      29     Note this class should not be inherited from directly, it is intended
#    (...)     32     directly.
#      33     """
#
# File ~/miniforge3/envs/Tencent/lib/python3.11/site-packages/qiskit/circuit/__init__.py:1373
#       1 # This code is part of Qiskit.
#       2 #
#       3 # (C) Copyright IBM 2017.
#    (...)     10 # copyright notice, and modified files need to carry a notice indicating
#      11 # that they have been altered from the originals.
#      13 r"""
#      14 =============================================
#      15 Quantum circuit model (:mod:`qiskit.circuit`)
#    (...)   1370         \end{pmatrix}
#    1371 """
# -> 1373 from qiskit._accelerate.circuit import (  # pylint: disable=unused-import
#    1374     Bit,
#    1375     Qubit,
#    1376     AncillaQubit,
#    1377     Clbit,
#    1378     QuantumRegister,
#    1379     AncillaRegister,
#    1380     ClassicalRegister,
#    1381     Register,
#    1382     Duration,
#    1383 )
#    1385 from .exceptions import CircuitError
#    1386 from . import _utils
#
# ModuleNotFoundError: No module named 'qiskit._accelerate.circuit'; 'qiskit._accelerate' is not a package

# %%
from qiskit import QuantumCircuit
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
from qiskit_ibm_runtime import QiskitRuntimeService, SamplerV2 as Sampler
 
service = QiskitRuntimeService()

# select the least busy machine
backend = service.least_busy(operational=True, simulator=False, min_num_qubits=127)
 
circuit = QuantumCircuit(2, 2)
circuit.h(0)
circuit.cx(0, 1)
circuit.measure_all()
 
pm = generate_preset_pass_manager(backend=backend, optimization_level=1)
isa_circuit = pm.run(circuit)
 
sampler = Sampler(backend)
job = sampler.run([isa_circuit])
result = job.result()
print(f" > Counts: {result[0].data.meas.get_counts()}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 3
#       1 from qiskit import QuantumCircuit
#       2 from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
# ----> 3 from qiskit_ibm_runtime import QiskitRuntimeService, SamplerV2 as Sampler
#       5 service = QiskitRuntimeService()
#       7 # select the least busy machine
#
# ModuleNotFoundError: No module named 'qiskit_ibm_runtime'
